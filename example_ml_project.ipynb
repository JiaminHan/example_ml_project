# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# load data
df=pd.read_csv('data.csv',index_col=0)
df.head()
# Out:
#    X1  X2    X3     X4   X5  X6  X7    X8    X9    X10  ...  X33  X34  X35  \
# 0   1  60  65.0   8450  NaN   7   5  2003  2003  196.0  ...    0    0    0
# 1   2  20  80.0   9600  NaN   6   8  1976  1976    0.0  ...    0    0    0
# 2   3  60  68.0  11250  NaN   7   5  2001  2002  162.0  ...    0    0    0
# 3   4  70  60.0   9550  NaN   7   5  1915  1970    0.0  ...    0    0    0
# 4   5  60  84.0  14260  NaN   8   5  2000  2000  350.0  ...    0    0    0
#
#    X36  X37  X38  X39  X40   X41     X42
# 0  NaN  NaN  NaN    0    2  2008  208500
# 1  NaN  NaN  NaN    0    5  2007  181500
# 2  NaN  NaN  NaN    0    9  2008  223500
# 3  NaN  NaN  NaN    0    2  2006  140000
# 4  NaN  NaN  NaN    0   12  2008  250000
#
# [5 rows x 42 columns]

# %%
#understand the data
df.shape
# Out:
# (1460, 42)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 0 to 1459
# Data columns (total 42 columns):
# X1     1460 non-null int64
# X2     1460 non-null int64
# X3     1201 non-null float64
# X4     1460 non-null int64
# X5     91 non-null object
# X6     1460 non-null int64
# X7     1460 non-null int64
# X8     1460 non-null int64
# X9     1460 non-null int64
# X10    1452 non-null float64
# X11    1460 non-null int64
# X12    1460 non-null int64
# X13    1460 non-null int64
# X14    1460 non-null int64
# X15    1460 non-null int64
# X16    1460 non-null int64
# X17    1460 non-null int64
# X18    1460 non-null int64
# X19    1460 non-null int64
# X20    1460 non-null int64
# X21    1460 non-null int64
# X22    1460 non-null int64
# X23    1460 non-null int64
# X24    1460 non-null int64
# X25    1460 non-null int64
# X26    1460 non-null int64
# X27    1379 non-null float64
# X28    1460 non-null int64
# X29    1460 non-null int64
# X30    1460 non-null int64
# ...

# %%
df.describe()
# Out:
#                 X1           X2           X3             X4           X6  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#                 X7           X8           X9          X10          X11  ...  \
# count  1460.000000  1460.000000  1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808  1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904    20.645407   181.066207   456.098091  ...
# ...

# %%
#handling null values
df.isnull().sum()
# Out:
# X1        0
# X2        0
# X3      259
# X4        0
# X5     1369
# X6        0
# X7        0
# X8        0
# X9        0
# X10       8
# X11       0
# X12       0
# X13       0
# X14       0
# X15       0
# X16       0
# X17       0
# X18       0
# X19       0
# X20       0
# X21       0
# X22       0
# X23       0
# X24       0
# X25       0
# X26       0
# X27      81
# X28       0
# X29       0
# X30       0
# X31       0
# X32       0
# X33       0
# X34       0
# X35       0
# X36    1453
# X37    1179
# X38    1406
# X39       0
# X40       0
# X41       0
# X42       0
# dtype: int64

# %%
#calculate missing percentage for each feature
mis_count=df.isnull().sum()
mis_percentage=df.isnull().sum()/len(df)
mis_table=pd.concat([mis_count,mis_percentage],axis=1)
mis_table.rename(columns={0:'mis_count',1:'mis_percentage'},inplace=True)
mis_table.sort_values(by='mis_percentage',ascending=False)
# Out:
#      mis_count  mis_percentage
# X36       1453        0.995205
# X38       1406        0.963014
# X5        1369        0.937671
# X37       1179        0.807534
# X3         259        0.177397
# X27         81        0.055479
# X10          8        0.005479
# X1           0        0.000000
# X32          0        0.000000
# X26          0        0.000000
# X28          0        0.000000
# X29          0        0.000000
# X30          0        0.000000
# X31          0        0.000000
# X35          0        0.000000
# X33          0        0.000000
# X34          0        0.000000
# X24          0        0.000000
# X39          0        0.000000
# X40          0        0.000000
# X41          0        0.000000
# X25          0        0.000000
# X22          0        0.000000
# X23          0        0.000000
# X13          0        0.000000
# X4           0        0.000000
# X6           0        0.000000
# X7           0        0.000000
# X8           0        0.000000
# ...

# %%
#drop columns have missing percentage larger than 60%
drop_columns=list(mis_table[mis_table['mis_percentage']>0.6].index)
drop_columns
# Out:
# ['X5', 'X36', 'X37', 'X38']

# %%
df.drop(columns=drop_columns,inplace=True)

# %%
mis_table[(mis_table['mis_percentage']>0)&(mis_table['mis_percentage']<=.6)].index
# Out:
# Index(['X3', 'X10', 'X27'], dtype='object')

# %%
#fillna
fillna_list=list(mis_table[(mis_table['mis_percentage']>0)&(mis_table['mis_percentage']<=.6)].index)
for i in fillna_list:
    df[i].fillna(df[i].median(),inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
# handling duplicates
df.duplicated().sum() #no duplicates identified
# Out:
# 0

# %%
# visualize target variable
plt.hist(df['X42'],bins=50);

# %%
# remove outliers
upper_bound=df['X42'].mean()+df['X42'].std()*3
lower_bound=df['X42'].mean()-df['X42'].std()*3
df=df[(df['X42']<upper_bound)&(df['X42']>lower_bound)]
plt.hist(df['X42'],bins=50);

# %%
# correlations
df.corr()['X42'].sort_values()
# Out:
# X24   -0.145244
# X32   -0.140363
# X2    -0.082756
# X7    -0.069833
# X17   -0.060149
# X1    -0.028112
# X20   -0.026684
# X41   -0.019633
# X39   -0.018489
# X12   -0.004591
# X35    0.036829
# X33    0.061720
# X40    0.081094
# X34    0.092677
# X23    0.172871
# X13    0.216787
# X19    0.231469
# X4     0.253476
# X22    0.276652
# X16    0.287319
# X31    0.313403
# X3     0.322352
# X30    0.330921
# X11    0.341000
# X10    0.418957
# X26    0.465635
# X27    0.480455
# X25    0.487621
# X9     0.536864
# X21    0.553524
# X8     0.557339
# X15    0.572255
# X14    0.582442
# X29    0.626092
# X28    0.651158
# X18    0.670485
# X6     0.796343
# X42    1.000000
# Name: X42, dtype: float64

# %%
fig,ax=plt.subplots(figsize=(15,10))
sns.heatmap(df.corr(),ax=ax);

# %%
fig,ax=plt.subplots(6,7,figsize=(18,15),sharey=True)
fig.subplots_adjust(hspace=.5)
columns=list(df.columns)[:-1]
for i,var in enumerate(columns):
    c=int(i/7)
    r=(i+7)%7
    sns.scatterplot(x=var,y='X42',data=df,ax=ax[c][r])
    ax[c][r].set(ylabel='X42')

# %%
# build model and evaluate
#data preprocess
obs=df.copy()
cat_list=['X19','X20','X21','X22','X24','X26','X28','X41']
for i in cat_list:
    obs[i]=obs[i].astype(str)

# %%
obs=pd.get_dummies(obs,columns=cat_list)

# %%
obs.columns
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12',
#        'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X23', 'X25', 'X27', 'X29',
#        'X30', 'X31', 'X32', 'X33', 'X34', 'X35', 'X39', 'X40', 'X42', 'X19_0',
#        'X19_1', 'X19_2', 'X19_3', 'X20_0', 'X20_1', 'X20_2', 'X21_0', 'X21_1',
#        'X21_2', 'X21_3', 'X22_0', 'X22_1', 'X22_2', 'X24_0', 'X24_1', 'X24_2',
#        'X24_3', 'X26_0', 'X26_1', 'X26_2', 'X26_3', 'X28_0', 'X28_1', 'X28_2',
#        'X28_3', 'X28_4', 'X41_2006', 'X41_2007', 'X41_2008', 'X41_2009',
#        'X41_2010'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
X=obs.drop(columns='X42')
y=obs['X42']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train.columns
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12',
#        'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X23', 'X25', 'X27', 'X29',
#        'X30', 'X31', 'X32', 'X33', 'X34', 'X35', 'X39', 'X40', 'X19_0',
#        'X19_1', 'X19_2', 'X19_3', 'X20_0', 'X20_1', 'X20_2', 'X21_0', 'X21_1',
#        'X21_2', 'X21_3', 'X22_0', 'X22_1', 'X22_2', 'X24_0', 'X24_1', 'X24_2',
#        'X24_3', 'X26_0', 'X26_1', 'X26_2', 'X26_3', 'X28_0', 'X28_1', 'X28_2',
#        'X28_3', 'X28_4', 'X41_2006', 'X41_2007', 'X41_2008', 'X41_2009',
#        'X41_2010'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn_pandas import DataFrameMapper
mapper = DataFrameMapper([ 
    (['X1', 'X2', 'X3', 'X4', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12',
       'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X23', 'X25', 'X27', 'X29',
       'X30', 'X31', 'X32', 'X33', 'X34', 'X35', 'X39', 'X40'], [StandardScaler()]),
        (['X19_0','X19_1', 'X19_2', 'X19_3', 'X20_0', 'X20_1', 'X20_2', 'X21_0', 'X21_1',
       'X21_2', 'X21_3', 'X22_0', 'X22_1', 'X22_2', 'X24_0', 'X24_1', 'X24_2',
       'X24_3', 'X26_0', 'X26_1', 'X26_2', 'X26_3', 'X28_0', 'X28_1', 'X28_2',
       'X28_3', 'X28_4', 'X41_2006', 'X41_2007', 'X41_2008', 'X41_2009',
       'X41_2010'], None)])

X_train=mapper.fit_transform(X_train)
X_test=mapper.transform(X_test)

# %%
#model selection
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error

# %%
def fit_and_evaluation(model):
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    mae=mean_absolute_error(y_test,y_pred)
    return mae

# %%
lasso=Lasso()
fit_and_evaluation(lasso)
# Out:
# 18219.188413237393

# %%
rf=RandomForestRegressor()
fit_and_evaluation(rf)
# Out:
# 18146.143578947365

# %%
gb=GradientBoostingRegressor()
fit_and_evaluation(gb)
# Out:
# 15599.611245282018

# %%
plt.scatter(gb.predict(X_test),y_test,alpha=0.5);

# %%
#optimization
from sklearn.model_selection import RandomizedSearchCV
param_dist = {"max_depth": np.arange(1,15,3),
              "max_features":['sqrt','log2'],
              'n_estimators':np.arange(10,250,50),
              'learning_rate':np.logspace(-2,0,4)}

# run randomized search
n_iter_search = 20
random_search = RandomizedSearchCV(gb, param_distributions=param_dist,
                                   n_iter=n_iter_search, cv=5)

random_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, error_score='raise',
#           estimator=GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=100, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False),
#           fit_params=None, iid=True, n_iter=20, n_jobs=1,
#           param_distributions={'max_depth': array([ 1,  4,  7, 10, 13]), 'max_features': ['sqrt', 'log2'], 'n_estimators': array([ 10,  60, 110, 160, 210]), 'learning_rate': array([0.01   , 0.04642, 0.21544, 1.     ])},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score='warn', scoring=None, verbose=0)

# %%
final_model=random_search.best_estimator_
fit_and_evaluation(final_model)
# Out:
# 15513.651697807123

# %%
plt.scatter(y_test,final_model.predict(X_test),alpha=0.2);
